# %% [markdown]
# **CHOCOLATE SALES ANALYSIS**

# %% [markdown]
# **Contributor**

# %% [markdown]
# Gordon Moenga

# %% [markdown]
# **1. OVERVIEW**
#
# The company seeks to improve its sales performance by gaining a deeper understanding of how its products, markets and sales channels contribute to overall business success. This project analyses two years of historical chocolate sales data (2022–2023) to evaluate business performance across products, countries, sales channels and sales representatives. The analysis focuses on identifying the primary drivers of revenue, shipment volume and sales performance, enabling stakeholders to make informed decisions regarding product strategy, market opportunities and operational efficiency.
#
# **Methodology:** A structured workflow was followed, covering data preparation, analysis and dashboard development.
#
# **Data Cleaning:** The dataset was cleaned by resolving missing values, correcting data types and improving data quality.
#
# **Exploratory Data Analysis:** Sales trends, patterns and relationships were explored using statistical analysis and visualisations.

# %% [markdown]
# **2. BUSINNESS UNDERSTANDING**

# %% [markdown]
# The company aims to strengthen its sales strategy by understanding the factors that influence business performance. By analysing two years of historical sales data, the analytics team evaluates product performance, regional sales, sales channels and revenue trends to identify opportunities that support informed business decisions and sustainable growth.

# %% [markdown]
# **2.1 Key Business Questions**
#
# Revenue Performance: How has the company's revenue performed over the two-year analysis period?
#
# Product Performance: Which products contribute the most to overall business performance?
#
# Market Performance: Which countries and sales channels generate the highest sales?
#
# Sales Performance: How effectively are sales representatives and marketing efforts driving revenue?

# %% [markdown]
# **2.2 Goal**

# %% [markdown]
# Increase revenue by identifying the highest-performing products and markets.
#
# Optimise sales strategies by evaluating the performance of sales channels and sales representatives.
#
# Improve operational planning by understanding sales trends and shipment volumes.
#
# Support strategic decision-making through interactive dashboards and business insights.

# %% [markdown]
# **3. DATA UNDERSTANDING**

# %% [markdown]
# The main data source was:
# [data/Chocolate_Sales.csv](https://www.kaggle.com/datasets/arjunmehta1992/chocolate-sales-in-20222023): Shows Sales Information, Product Information, Market Information, and Sales Performance Information.

# %% [markdown]
# **4. DATA PREPARATION AND IMPORTING LIBRARIES**

# %% [markdown]
# **4.1 DATA LOADING**

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
chocolate_sales = pd.read_csv("Chocolate_Sales.csv")

# %%
chocolate_sales.head()
# Out:
#      Order_ID            Product    Country Channel    Salesperson  \
# 0  ORD-069833   Truffle Gift Box  Australia  Retail    Arjun Mehta
# 1  ORD-090726       85% Dark Bar  Australia  Retail    Arjun Mehta
# 2  ORD-042159       70% Dark Bar      Japan  Retail  Hannah Müller
# 3  ORD-197166  Hazelnut Milk Bar    Germany  Retail    Arjun Mehta
# 4  ORD-112162  Almond Crunch Bar  Australia  Retail      Yuki Sato
#
#    Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped  \
# 0  12/11/2022           3.5          13.72           202.03             71
# 1   3/14/2023           9.4           3.30            55.18             84
# 2  12/21/2023           4.9          18.21            60.65             35
# 3  12/18/2023          15.0           2.66            52.00             92
# 4   8/18/2023           4.4           2.75           187.44            214
#
#    Amount
# 0  912.31
# 1  245.91
# 2   583.7
# 3  211.27
# 4  549.69

# %%
chocolate_sales.tail()
# Out:
#           Order_ID             Product    Country    Channel    Salesperson  \
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
#         Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  \
# 199995   5/27/2022          10.6           3.39           186.19
# 199996    9/6/2022          17.3           3.07            42.28
# 199997   6/16/2022          18.3           2.74           100.19
# 199998  10/14/2022           9.3          14.30            29.96
# 199999   1/25/2022           7.2           3.01           270.86
#
#         Boxes_Shipped  Amount
# 199995            125  418.56
# 199996            148  366.47
# ...

# %% [markdown]
# **4.2 DETAILED DATA CLEANING**

# %%
# determining dataset dimension
chocolate_sales.shape
# Out:
# (200000, 11)

# %%
# determining total columns
chocolate_sales.columns
# Out:
# Index(['Order_ID', 'Product', 'Country', 'Channel', 'Salesperson',
#        'Order_Date', 'Discount_Pct', 'Price_per_Box', 'Marketing_Spend',
#        'Boxes_Shipped', 'Amount'],
#       dtype='object')

# %%
# identifying datatypes for each column
chocolate_sales.dtypes
# Out:
# Order_ID            object
# Product             object
# Country             object
# Channel             object
# Salesperson         object
# Order_Date          object
# Discount_Pct       float64
# Price_per_Box      float64
# Marketing_Spend    float64
# Boxes_Shipped        int64
# Amount              object
# dtype: object

# %%
# detailed information about each column
chocolate_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Order_ID         200000 non-null  object
#  1   Product          200000 non-null  object
#  2   Country          200000 non-null  object
#  3   Channel          200000 non-null  object
#  4   Salesperson      200000 non-null  object
#  5   Order_Date       199563 non-null  object
#  6   Discount_Pct     199511 non-null  float64
#  7   Price_per_Box    199543 non-null  float64
#  8   Marketing_Spend  199539 non-null  float64
#  9   Boxes_Shipped    200000 non-null  int64
#  10  Amount           200000 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 16.8+ MB

# %%
# detailed summary statistics for the dataset
chocolate_sales.describe()
# Out:
#         Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped
# count  199511.000000  199543.000000    199539.000000  200000.000000
# mean       13.107457       5.911507        95.450141     139.584105
# std         6.374477       4.954976        66.243760     118.665393
# min         0.000000       2.040000         4.300000   -1642.000000
# 25%         8.300000       2.950000        52.270000      67.000000
# 50%        12.600000       3.280000        78.850000     113.000000
# 75%        17.500000       4.570000       118.710000     180.000000
# max        38.300000      21.650000       798.222443    3811.000000

# %%
# determining missing values for each column
chocolate_sales.isnull().sum()
# Out:
# Order_ID             0
# Product              0
# Country              0
# Channel              0
# Salesperson          0
# Order_Date         437
# Discount_Pct       489
# Price_per_Box      457
# Marketing_Spend    461
# Boxes_Shipped        0
# Amount               0
# dtype: int64

# %%
# checking for duplicated rows
chocolate_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
# determining unique values
chocolate_sales.nunique()
# Out:
# Order_ID           200000
# Product                12
# Country                 5
# Channel                 3
# Salesperson            25
# Order_Date           1134
# Discount_Pct         2517
# Price_per_Box        1381
# Marketing_Spend     27319
# Boxes_Shipped        1521
# Amount              85605
# dtype: int64

# %%
# determining unique values for the 'Country' column
chocolate_sales.Country.unique()
# Out:
# array(['Australia', 'Japan', 'Germany', 'Brazil', 'India'], dtype=object)

# %%
chocolate_sales[chocolate_sales.isnull().any(axis=1)]
# Out:
#           Order_ID               Product    Country    Channel  \
# 72      ORD-027870     Pralines Gift Box     Brazil     Retail
# 81      ORD-134997       Choco Coins Bag      Japan  Wholesale
# 174     ORD-085354          70% Dark Bar  Australia     Online
# 180     ORD-104088      Truffle Gift Box     Brazil     Retail
# 190     ORD-128088     Pralines Gift Box  Australia     Retail
# ...            ...                   ...        ...        ...
# 199594  ORD-099370     Almond Crunch Bar  Australia     Retail
# 199604  ORD-144195      Milk Classic Bar    Germany     Retail
# 199731  ORD-033532          70% Dark Bar  Australia  Wholesale
# 199750  ORD-025224          70% Dark Bar     Brazil     Online
# 199917  ORD-099089  Mixed Assortment Box    Germany  Wholesale
#
#             Salesperson  Order_Date  Discount_Pct  Price_per_Box  \
# 72            Yuki Sato    3/3/2022           7.1            NaN
# 81          Rohan Patel   3/26/2022           7.7            NaN
# ...

# %%
# Converting datatype into datetime64[ns] for order_date column
chocolate_sales.Order_Date  = pd.to_datetime(chocolate_sales.Order_Date, format="mixed")

# %%
# checking to see if datatype is datetime64[ns]
chocolate_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Order_ID         200000 non-null  object
#  1   Product          200000 non-null  object
#  2   Country          200000 non-null  object
#  3   Channel          200000 non-null  object
#  4   Salesperson      200000 non-null  object
#  5   Order_Date       199563 non-null  object
#  6   Discount_Pct     199511 non-null  float64
#  7   Price_per_Box    199543 non-null  float64
#  8   Marketing_Spend  199539 non-null  float64
#  9   Boxes_Shipped    200000 non-null  int64
#  10  Amount           200000 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 16.8+ MB

# %%
# Dropping all null values
chocolate_sales = chocolate_sales.dropna()

# %%
# verifying the number of null of null values after dropping
chocolate_sales.isnull().sum()
# Out:
# Order_ID             0
# Product              0
# Country              0
# Channel              0
# Salesperson          0
# Order_Date         437
# Discount_Pct       489
# Price_per_Box      457
# Marketing_Spend    461
# Boxes_Shipped        0
# Amount               0
# dtype: int64

# %%
# confirm new shape
chocolate_sales.shape
# Out:
# (200000, 11)

# %% [markdown]
# The dataset contained missing values in Order_Date, Discount_Pct, Price_per_Box, and Marketing_Spend. Only 1,603 out of 200,000 records (0.80%) were affected. Because the proportion was very small, the incomplete records were removed using dropna(). This preserved over 99% of the dataset while avoiding assumptions that could bias the analysis.

# %%
# view dtype for the 'Amount' column
print(chocolate_sales.Amount.dtype)
print(chocolate_sales.Amount.apply(type).value_counts())
# Out:
# object
# Amount
# <class 'str'>    200000
# Name: count, dtype: int64

# %%
# converting dtype from object to numeric
# .str.replace("$", "", regex=False) for values having '$'
# .str.replace(",", "", regex=False) for values having commas
chocolate_sales.Amount = (
    chocolate_sales.Amount.astype(str)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False).astype(float)
)

# %%
# confirm new dtype
print(chocolate_sales.Amount.dtype)
# Out:
# float64

# %%
# checking for negative values in the dataset
(chocolate_sales.Boxes_Shipped < 0).sum()
# Out:
# np.int64(1956)

# %%
chocolate_sales[(chocolate_sales.Boxes_Shipped < 0)].head(10)
# Out:
#        Order_ID               Product    Country    Channel    Salesperson  \
# 301  ORD-062584          70% Dark Bar  Australia     Retail    Arjun Mehta
# 318  ORD-069620          70% Dark Bar    Germany     Online   Lucas Walker
# 324  ORD-166180          70% Dark Bar  Australia     Retail   Priya Sharma
# 339  ORD-058464      Milk Classic Bar     Brazil     Retail   Priya Sharma
# 442  ORD-176773          70% Dark Bar  Australia  Wholesale   Priya Sharma
# 462  ORD-087013     Almond Crunch Bar  Australia     Retail   Ananya Gupta
# 512  ORD-065573  Mixed Assortment Box     Brazil     Retail    Arjun Mehta
# 694  ORD-172166    Salted Caramel Bar  Australia     Retail  Gabriel Silva
# 745  ORD-192329          70% Dark Bar  Australia     Retail    Arjun Mehta
# 758  ORD-146664       Choco Coins Bag  Australia     Online    Rohan Patel
#
#     Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped  \
# ...

# %%
# statistical summary for rows that have negative values in reference to amount
chocolate_sales[(chocolate_sales.Boxes_Shipped < 0)]["Amount"].describe()
# Out:
# count    1956.000000
# mean      516.481217
# std       359.852027
# min        73.320000
# 25%       287.855000
# 50%       419.265000
# 75%       618.222500
# max      4285.440000
# Name: Amount, dtype: float64

# %%
chocolate_sales[chocolate_sales["Boxes_Shipped"] < 0][["Boxes_Shipped", "Amount"]].describe()
# Out:
#        Boxes_Shipped       Amount
# count    1938.000000  1938.000000
# mean     -138.993292   516.930996
# std       118.724948   360.195374
# min     -1642.000000    73.320000
# 25%      -177.000000   287.622500
# 50%      -112.000000   420.130000
# 75%       -66.000000   618.367500
# max        -3.000000  4285.440000

# %% [markdown]
# During data validation, 1,938 records were found to contain negative values in the `Boxes_Shipped` column while the corresponding revenue (`Amount`) remained positive.
# Without additional business context, these records were retained to preserve the integrity of the original dataset. The anomaly has been documented as a potential data quality issue that should be investigated with the data owner.

# %% [markdown]
# **5. DATA ANALYSIS AND VISUALIZATION**

# %% [markdown]
# Overall Performance

# %%
# calculating total revenue generated
total_revenue = chocolate_sales.Amount.sum()
print(f"Total Revenue: ${total_revenue:,}")
# Out:
# Total Revenue: $102,572,394.94

# %%
# calculating the average amount for the orders made
average_order_value = chocolate_sales.Amount.mean()
print(f"Average Order Value: ${average_order_value:,.2f}")
# Out:
# Average Order Value: $512.86

# %%
# calculating toral amount of orders
total_orders = chocolate_sales.Amount.nunique()
print(f"Total Orders: {total_orders:,}")
# Out:
# Total Orders: 83,404

# %%
# calculating total amount of boxes shipped to different countries
total_boxes = chocolate_sales.Boxes_Shipped.sum()
print(f"Total Boxes Shipped: {total_boxes:,}")
# Out:
# Total Boxes Shipped: 27,916,821

# %% [markdown]
# Insight:
# The company generated $101,746,622.98 in total revenue from 200,000 orders. The total number of boxes shipped was 27,691,275. These KPIs provide a high-level overview of business performance and will serve as the primary metrics displayed on the executive dashboard.

# %%
# analysing total revenue generated by each product 
product_sales = (
    chocolate_sales.groupby('Product', as_index=False)['Amount']
    .sum().sort_values('Amount', ascending=False)
)
product_sales
# Out:
#                  Product       Amount
# 0           70% Dark Bar  26362710.09
# 7   Mixed Assortment Box  19535348.24
# 10      Truffle Gift Box  19410521.53
# 5       Milk Classic Bar   6249523.16
# 2      Almond Crunch Bar   5793935.50
# 8      Pralines Gift Box   5763680.30
# 3        Choco Coins Bag   4781446.11
# 6          Mint Dark Bar   3513015.85
# 11       White Choco Bar   3225808.32
# 1           85% Dark Bar   2968453.79
# 9     Salted Caramel Bar   2802314.01
# 4      Hazelnut Milk Bar   2165638.04

# %%
# visualising how each product performed in terms of total revenue
plt.figure(figsize=(10,6))
sns.barplot(x=product_sales.Amount, y=product_sales.Product)

plt.title("Revenue By Product")
plt.xlabel("Revenue ($) ")
plt.show()

# %% [markdown]
# Insight:
# 70% Dark Bar generated the highest revenue, followed by Mixed Assortment Box and Truffle Gift Box. These products appear to be the company's strongest revenue drivers and should remain a priority for sales and marketing efforts.

# %%
# analysing revenue generated by individual countries
country_sales = chocolate_sales.groupby('Country', as_index=False)['Amount'].sum()
country_sales
# Out:
#      Country       Amount
# 0  Australia  42433722.62
# 1     Brazil  36628716.00
# 2    Germany  11358009.06
# 3      India   6490214.02
# 4      Japan   5661733.24

# %%
# visualising coountry performance based on revenue generated
plt.figure(figsize=(8,5))
sns.barplot(x=country_sales.Country, y=country_sales.Amount)
plt.title("Revenue By Country")
plt.xlabel("Country")
plt.ylabel("Revenue ($) ")
plt.show()

# %% [markdown]
# Insight:
# Australia contributed the highest revenue, while Japan recorded the lowest. This suggests stronger market performance in Australia and potential opportunities for growth in Japan.

# %%
# analysing renenue generated by the three sales channel that distributed the products
channel_sales = (
    chocolate_sales.groupby('Channel', as_index=False)['Amount']
    .sum().sort_values('Amount', ascending=False)
)
channel_sales
# Out:
#      Channel       Amount
# 1     Retail  53793511.25
# 2  Wholesale  37481461.34
# 0     Online  11297422.35

# %%
# visualising saleschannel performance in terms of revenue generated
plt.figure(figsize=(8,4))
sns.barplot(x=channel_sales.Channel, y=channel_sales.Amount)
plt.title("Revenues By Sales Channel")
plt.ylabel("Revenue ($)")
plt.show()

# %% [markdown]
# Insight:
# Retail generated the highest revenue among all sales channels, making it the company's strongest sales channel during the analysis period. Wholesale ranked second, while Online contributed the lowest revenue. This distribution suggests that the business relies heavily on traditional sales channels, while the online channel may present an opportunity for further investment and growth.

# %%
# identifying the top 10 performing salespeople based on total revenue generated
top_sales = (
    chocolate_sales.groupby('Salesperson', as_index=False)['Amount']
    .sum().head(10).sort_values('Amount', ascending=False)
)
top_sales
# Out:
#      Salesperson       Amount
# 1    Arjun Mehta  34701218.71
# 6   Emily Clarke   9126199.94
# 7   Felix Becker   2454436.87
# 3  Camila Santos   1934021.54
# 2  Beatriz Souza   1735575.27
# 9  Hannah Müller   1352552.78
# 8  Gabriel Silva   1025629.05
# 5   Daniel Weber   1023695.53
# 4  Carlos Mendez    809111.61
# 0   Ananya Gupta    769942.69

# %%
# visualising how each of the top 10 salespeople performed
plt.figure(figsize=(10,5))
sns.barplot(x=top_sales.Amount, y=top_sales.Salesperson)
plt.title("Top 10 Salespeople By Revenue")
plt.xlabel("Revenue ($)")
plt.ylabel("Salesperson")
plt.show()

# %% [markdown]
# Insight:
# Arjun Mehta was the top performing salesperson generating a total revenue of 34,701,218.71 USD

# %%
# Additional columns to view revenue trend
chocolate_sales['Year'] = chocolate_sales['Order_Date'].dt.year
chocolate_sales['Month'] = chocolate_sales['Order_Date'].dt.month
chocolate_sales
# Out:
#           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...

# %%
# identifying total revenue generated monthly throughout the year
monthly_sales = (
    chocolate_sales.groupby('Month', as_index=False)['Amount']
    .sum().sort_values('Amount', ascending=False)
)
monthly_sales
# Out:
#     Month       Amount
# 11   12.0  11130497.86
# 10   11.0   9792144.32
# 0     1.0   9691731.32
# 9    10.0   8798840.27
# 8     9.0   8107308.71
# 1     2.0   8103098.52
# 7     8.0   8090864.34
# 2     3.0   8011694.54
# 4     5.0   7940067.79
# 3     4.0   7737805.89
# 6     7.0   7616557.59
# 5     6.0   7317212.49

# %%
# Visualising monthly performance based on total revenue earned for the company
plt.figure(figsize=(14,5))
sns.barplot(x=monthly_sales.Month, y=monthly_sales.Amount)
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue ($)")
plt.show()

# %% [markdown]
# Insight:
# December recorded the highest monthly revenue, followed by November, and January. June had the lowest revenue.
# The results suggest that sales fluctuate throughout the year, with stronger performance towards the end of the year. This pattern can help the business plan inventory, marketing campaigns, and sales strategies more effectively.

# %%
# visualising revenue distribution
plt.figure(figsize=(10,5))
sns.histplot(chocolate_sales.Amount, bins=50, kde=True)
plt.title("Distribution of Order Revenue")
plt.xlabel("Revenue ($)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Insight:
# The distribution of order revenue is positively skewed, with most orders generating relatively low to moderate revenue. As order revenue increases, the number of orders decreases significantly, resulting in a long tail of high-value orders.
# This indicates that the company's sales are primarily driven by a large number of smaller transactions, while a smaller number of high-value orders contribute to the overall revenue.

# %%
# visualising how initial market spend affected the total revenue generated for the company
plt.figure(figsize=(8,6))
sns.regplot(x=chocolate_sales.Marketing_Spend, y=chocolate_sales.Amount, line_kws={'color':'red'})
plt.title("Marketing Spend vs Revenue")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# I used a redplot to see the "Line of Best Fit." This helps us understand if spending an extra

# %%
# Correlation coefficient
chocolate_sales.Marketing_Spend.corr(chocolate_sales.Amount)
# Out:
# np.float64(0.37264357756719596)

# %% [markdown]
# Insight:
# The scatter plot and correlation analysis indicate a moderate positive relationship between marketing spend and revenue (correlation = 0.373). While revenue generally tends to increase as marketing spend increases, the relationship is not strong, and there is considerable variation in revenue across different levels of marketing spend.
# This suggests that marketing spend contributes to revenue generation, but other factors such as product type, sales channel, pricing, and customer demand also influence sales performance.

# %%
# saving the new dataset for further visualising in PowerBi
chocolate_sales.to_csv("Chocolate_Sales_Cleaned.csv", index=False)

# %% [markdown]
# **6. RECOMMENDATIONS**

# %% [markdown]
# 1. Strengthen High-Performing Products
# Focus sales and marketing efforts on the highest-performing products to maximise revenue while identifying opportunities to improve lower-performing product lines.
#
# 2. Expand High-Performing Markets
# Increase investment in countries with the strongest sales performance while exploring strategies to grow revenue in underperforming markets.
#
# 3. Optimise Sales Channels
# Build on the success of the retail channel and develop targeted initiatives to improve the performance of the wholesale and online channels.
#
# 4. Enhance Sales Performance
# Recognise top-performing sales representatives and share their best practices to improve the performance of the wider sales team.
#
# 5. Optimise Marketing Investment
# Allocate marketing budgets strategically by prioritising campaigns that demonstrate the greatest impact on revenue generation.

# %% [markdown]
# **7. CONCLUSION**

# %% [markdown]
# Analysis of two years of chocolate sales data (2022–2023) revealed key insights into the company's revenue, products, markets and sales performance. The business generated **$101.75 million** in total revenue, with sales remaining relatively stable throughout the analysis period and peaking in **December**, indicating seasonal demand. Product analysis showed that a small number of products contributed a significant share of total revenue, while market analysis identified the company's strongest-performing countries and confirmed that the **Retail** sales channel generated the highest revenue, followed by **Wholesale** and **Online**. Sales performance analysis also identified the top-performing sales representatives and found a **moderate positive relationship** between marketing expenditure and revenue, suggesting that marketing investment contributes to sales growth alongside other business factors.
# The findings highlight opportunities to increase revenue by strengthening high-performing products, expanding successful markets, optimising sales channels and allocating marketing resources more effectively. By combining Python for data preparation and analysis with Power BI for interactive reporting, the project demonstrates how data analytics can transform raw sales data into actionable business insights that support informed strategic and operational decision-making.
